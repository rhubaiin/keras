# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df1 = pd.read_csv('/kaggle/input/kk-inventory/inventory_consumed.csv')
df2 = pd.read_csv('/kaggle/input/kk-inventory/inventory_ordered.csv')

# %% [markdown]
# 1. df1 is train set, check trend for how much is consumed, then predict next timeline of consumption
# 2. df2 is order for inventory, used to verify predicted timeline to actual orders

# %%
df1

# %%
df1.dtypes

# %%
df2

# %%
df1['SKU_CAT'].unique()

# %%
df1['SKU_CAT'].describe()

# %%
unique_count = len(df1['SKU_CAT'].unique())
unique_count

# %%
df2['SKU_CAT'].unique()

# %%
df2['SKU_CAT'].describe()

# %%
unique_count = len(df2['SKU_CAT'].unique())
unique_count

# %%
# Get the unique items from both DataFrames
unique_df1 = set(df1['SKU_CAT'].unique())
unique_df2 = set(df2['SKU_CAT'].unique())

# Find the unique items that are in df1 but not in df2
unique_in_df1_not_in_df2 = unique_df1 - unique_df2

# Find the unique items that are in df2 but not in df1
unique_in_df2_not_in_df1 = unique_df2 - unique_df1

print("Items in df1 but not in df2:", unique_in_df1_not_in_df2)
print("Items in df2 but not in df1:", unique_in_df2_not_in_df1)

# %%
df1['SKU_NAME'].unique()

# %%
df1['SKU_NAME'].describe()

# %%
df2['SKU_NAME'].unique()

# %%
df2['SKU_NAME'].describe()

# %%
# Get the unique items from both DataFrames
unique_df1 = set(df1['SKU_NAME'].unique())
unique_df2 = set(df2['SKU_NAME'].unique())

# Find the unique items that are in df1 but not in df2
unique_in_df1_not_in_df2 = unique_df1 - unique_df2

# Find the unique items that are in df2 but not in df1
unique_in_df2_not_in_df1 = unique_df2 - unique_df1

print("Items in df1 but not in df2:", unique_in_df1_not_in_df2)
print("Items in df2 but not in df1:", unique_in_df2_not_in_df1)

# %%
df1.iloc[70:100]

# %%
df2.iloc[70:100]

# %%
df1['QTY_OUT'].describe()

# %%
# df2 = df2[df2['SKU_NAME'] == 'VEG - FRY PEANUT (OEM) [500GM/16PKT/CTN]']
# df3 = df2.groupby(['DO_DATE']).agg({'FULFILLED_QTY': 'sum'})
# import matplotlib

# df3.plot(kind='bar')

# df1.groupby(['SKU_NAME', 'SKU_CAT'])['QTY_OUT'].count()
# df1.fillna('unknown')

# %%
import pandas as pd

# Assuming df is your DataFrame
df1['MOV_DATE'] = pd.to_datetime(df1['MOV_DATE'])
df1

# %%
df1 = df1.sort_values(by='MOV_DATE').reset_index(drop=True)
df1

# %%
import numpy as np

df1['Time'] = np.arange(len(df1.index))

df1

# %%
from pathlib import Path
from warnings import simplefilter

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df1_meat = df1[df1['SKU_CAT'] == 'MEAT']
# df1_meat['Time'] = np.arange(len(df1_meat.index))

# %%
df1_meat

# %%
# Types of operations
# # Sum of 'QTY_OUT' for each date
# meat_sum = df1_meat.groupby('MOV_DATE')['QTY_OUT'].sum().reset_index()

# # Minimum and Maximum of 'QTY_OUT' for each date
# meat_min_max = df1_meat.groupby('MOV_DATE')['QTY_OUT'].agg(['min', 'max']).reset_index()

# # Count of entries for each date
# meat_count = df1_meat.groupby('MOV_DATE')['QTY_OUT'].count().reset_index()

# # Cumulative sum of 'QTY_OUT' within each group
# meat_cumsum = df1_meat.groupby('MOV_DATE')['QTY_OUT'].cumsum().reset_index()

# # Custom aggregation: Mean and Standard Deviation
# meat_custom_agg = df1_meat.groupby('MOV_DATE')['QTY_OUT'].agg(['mean', 'std']).reset_index()

# meat = df.groupby('column1')['column2'].agg(['mean', 'sum', 'min'])

# %%
meat_sum = df1_meat.groupby('MOV_DATE')['QTY_OUT'].agg(['mean', 'sum']).reset_index()

# %%
meat_sum = df1_meat.groupby('MOV_DATE')['QTY_OUT'].mean().reset_index()

# %%
meat_sum

# %%
meat_sum['MOV_DATE'] = pd.to_datetime(meat_sum['MOV_DATE'], format='%A, %B %d, %Y')
meat_sum = meat_sum.sort_values(by='MOV_DATE').reset_index(drop=True)

# %%
meat_sum

# %%
meat_sum['Time'] = np.arange(len(meat.index))
meat_sum

# %% [markdown]
# 1. TIME STEPS & LAGS

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
fig, ax = plt.subplots()
ax.plot('Time', 'QTY_OUT', data=meat_sum, color='0.75')
ax = sns.regplot(x='Time', y='QTY_OUT', data=meat_sum, ci=None, scatter_kws=dict(color='0.25'))
ax.set_title('Time Plot of Meat Sales');

# %%
from sklearn.linear_model import LinearRegression

# Training data
X = meat_sum.loc[:, ['Time']]  # features
y = meat_sum.loc[:, 'QTY_OUT']  # target

# Train the model
model = LinearRegression()
model.fit(X, y)

# Store the fitted values as a time series with the same time index as
# the training data
y_pred = pd.Series(model.predict(X), index=X.index)

# %%
# YOUR CODE HERE: Create a lag feature from the target 'sales'
lag_1 = meat_sum['QTY_OUT'].shift(1)

meat_sum['lag_1'] = lag_1  # add to dataframe

X = meat_sum.loc[:, ['lag_1']].dropna()  # features
y = meat_sum.loc[:, 'QTY_OUT']  # target
y, X = y.align(X, join='inner')  # drop corresponding values in target

# YOUR CODE HERE: Create a LinearRegression instance and fit it to X and y.
model = LinearRegression()
model.fit(X, y)
# YOUR CODE HERE: Create Store the fitted values as a time series with
# the same time index as the training data
y_pred = pd.Series(model.predict(X), index=X.index)

# %%
fig, ax = plt.subplots()
ax.plot(X['lag_1'], y, '.', color='0.25')
ax.plot(X['lag_1'], y_pred)
ax.set(aspect='equal', ylabel='qty_out', xlabel='lag_1', title='Lag Plot of Meat Sales')

# %%
meat_sum['preds'] = y_pred

# %%
meat_sum

# %%
import matplotlib.pyplot as plt

# Plotting
plt.figure(figsize=(10, 6))

# Plot 'qty_out' vs 'time'
plt.plot(meat_sum['Time'], meat_sum['QTY_OUT'], label='Quantity Out', marker='o')

# Plot 'preds' vs 'time'
plt.plot(meat_sum['Time'], meat_sum['preds'], label='Predictions', marker='x')

# Adding labels and title
plt.xlabel('Time')
plt.ylabel('Values')
plt.title('Quantity Out vs Predictions over Time')

# Adding a legend
plt.legend()

# Optional: adding grid lines for better readability
plt.grid(True)

# Display the plot
plt.show()

# %% [markdown]
# **TRENDS**

# %%
from pathlib import Path
from warnings import simplefilter

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

simplefilter("ignore")  # ignore warnings to clean up output cells

# %%
meat1 = pd.read_csv('/kaggle/input/kk-inventory/inventory_consumed.csv', parse_dates=["MOV_DATE"])

# %%
meat1 = meat1[meat1['SKU_CAT'] == 'MEAT']

# %%
meat1 = meat1.groupby(['MOV_DATE'])['QTY_OUT'].mean().reset_index()

# %%
meat1

# %%
meat1

# %%
moving_average = meat1['QTY_OUT'].rolling(
    window=365,       # 365-day window
    center=True,      # puts the average at the center of the window
    min_periods=182,  # choose about half the window size
).mean()              # compute the mean (could also do median, std, min, max, ...)

ax = meat1['QTY_OUT'].plot(style=".", color="0.5")
moving_average.plot(
    ax=ax, linewidth=3, title="Meat Sales - 365-Day Moving Average", legend=False,
);

# %%
ax = meat1.plot(**plot_params, alpha=0.5)
ax = trend.plot(ax=ax, linewidth=3)

# %%
from statsmodels.tsa.deterministic import DeterministicProcess

dp = DeterministicProcess(
    index=meat1.index,  # dates from the training data
    constant=True,       # dummy feature for the bias (y_intercept)
    order=3,             # the time dummy (trend)
    drop=True,           # drop terms if necessary to avoid collinearity
)
# `in_sample` creates features for the dates given in the `index` argument
X = dp.in_sample()

X.head()

# %%
from sklearn.linear_model import LinearRegression

y = meat1['QTY_OUT']  # the target

# The intercept is the same as the `const` feature from
# DeterministicProcess. LinearRegression behaves badly with duplicated
# features, so we need to be sure to exclude it here.
model = LinearRegression(fit_intercept=False)
model.fit(X, y)

y_pred = pd.Series(model.predict(X), index=X.index)

# %%
y_pred

# %%
ax = meat1['QTY_OUT'].plot(style=".", color="0.5", title="Meat Sales - Linear Trend")
_ = y_pred.plot(ax=ax, linewidth=3, label="Trend")

# %%
ax = y.plot(alpha=0.5, title="Average Sales", ylabel="items sold")
ax = y_pred.plot(ax=ax, linewidth=3, label="Trend", color='C0')
ax = y_fore.plot(ax=ax, linewidth=3, label="Trend Forecast", color='C3')
ax.legend();

# %%
X = dp.out_of_sample(steps=30)

y_fore = pd.Series(model.predict(X), index=X.index)

y_fore.head()

# %%
# ax = meat1["2024-08-06":].plot(title="Tunnel Traffic - Linear Trend Forecast", **plot_params)
# ax = y_pred["2024-08-06":].plot(ax=ax, linewidth=3, label="Trend")
# ax = y_fore.plot(ax=ax, linewidth=3, label="Trend Forecast", color="C3")
# _ = ax.legend()

# %% [markdown]
# **SEASONALITY**

# %%
from pathlib import Path
from warnings import simplefilter

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression
from statsmodels.tsa.deterministic import CalendarFourier, DeterministicProcess

simplefilter("ignore")

# Set Matplotlib defaults
plt.style.use("seaborn-whitegrid")
plt.rc("figure", autolayout=True, figsize=(11, 5))
plt.rc(
    "axes",
    labelweight="bold",
    labelsize="large",
    titleweight="bold",
    titlesize=16,
    titlepad=10,
)
plot_params = dict(
    color="0.75",
    style=".-",
    markeredgecolor="0.25",
    markerfacecolor="0.25",
    legend=False,
)
# %config InlineBackend.figure_format = 'retina'


# annotations: https://stackoverflow.com/a/49238256/5769929
def seasonal_plot(X, y, period, freq, ax=None):
    if ax is None:
        _, ax = plt.subplots()
    palette = sns.color_palette("husl", n_colors=X[period].nunique(),)
    ax = sns.lineplot(
        x=freq,
        y=y,
        hue=period,
        data=X,
        ci=False,
        ax=ax,
        palette=palette,
        legend=False,
    )
    ax.set_title(f"Seasonal Plot ({period}/{freq})")
    for line, name in zip(ax.lines, X[period].unique()):
        y_ = line.get_ydata()[-1]
        ax.annotate(
            name,
            xy=(1, y_),
            xytext=(6, 0),
            color=line.get_color(),
            xycoords=ax.get_yaxis_transform(),
            textcoords="offset points",
            size=14,
            va="center",
        )
    return ax


def plot_periodogram(ts, detrend='linear', ax=None):
    from scipy.signal import periodogram
    fs = pd.Timedelta("365D") / pd.Timedelta("1D")
    freqencies, spectrum = periodogram(
        ts,
        fs=fs,
        detrend=detrend,
        window="boxcar",
        scaling='spectrum',
    )
    if ax is None:
        _, ax = plt.subplots()
    ax.step(freqencies, spectrum, color="purple")
    ax.set_xscale("log")
    ax.set_xticks([1, 2, 4, 6, 12, 26, 52, 104])
    ax.set_xticklabels(
        [
            "Annual (1)",
            "Semiannual (2)",
            "Quarterly (4)",
            "Bimonthly (6)",
            "Monthly (12)",
            "Biweekly (26)",
            "Weekly (52)",
            "Semiweekly (104)",
        ],
        rotation=30,
    )
    ax.ticklabel_format(axis="y", style="sci", scilimits=(0, 0))
    ax.set_ylabel("Variance")
    ax.set_title("Periodogram")
    return ax

# %%
meattt = pd.read_csv('/kaggle/input/kk-inventory/inventory_consumed.csv', parse_dates=["MOV_DATE"])
meattt = meattt[meattt['SKU_CAT'] == 'MEAT']
meattt = meattt.groupby(['MOV_DATE', 'SKU_CAT'])['QTY_OUT'].mean().sort_index()
meattt

# %%
meattt = meattt.reset_index()

# %%
meattt

# %%
meattt = meattt.set_index("MOV_DATE").to_period("D")

# %%
meattt

# %%
X = meattt.copy()

# days within a week
X["day"] = X.index.dayofweek  # the x-axis (freq)
X["week"] = X.index.week  # the seasonal period (period)

# days within a year
X["dayofyear"] = X.index.dayofyear
X["year"] = X.index.year
fig, (ax0, ax1) = plt.subplots(2, 1, figsize=(11, 6))
seasonal_plot(X, y="QTY_OUT", period="week", freq="day", ax=ax0)
seasonal_plot(X, y="QTY_OUT", period="year", freq="dayofyear", ax=ax1);

# %%
X

# %%
# X.index.dayofyear:

# X.index refers to the index of the DataFrame X. This index is expected to be of a DatetimeIndex type, meaning it contains dates.
# .dayofyear is an attribute of DatetimeIndex that returns the day of the year for each date. For example, January 1st would return 1, and December 31st would return 365 (or 366 in a leap year).
# X["dayofyear"] = X.index.dayofyear creates a new column called "dayofyear" in the DataFrame X and assigns to it the day of the year for each row based on the date in the index.
# X["year"] = X.index.year:

# Similarly, .year is an attribute of DatetimeIndex that returns the year of each date.
# X["year"] = X.index.year creates a new column called "year" in the DataFrame X and assigns to it the year for each row based on the date in the index.

# %%
plot_periodogram(meattt.QTY_OUT);

# %%
from statsmodels.tsa.deterministic import CalendarFourier, DeterministicProcess

fourier = CalendarFourier(freq="W", order=52)  # 10 sin/cos pairs for "A"nnual seasonality

dp = DeterministicProcess(
    index=meattt.index,
    constant=True,               # dummy feature for bias (y-intercept)
    order=3,                     # trend (order 1 means linear)
    seasonal=True,               # weekly seasonality (indicators)
    additional_terms=[fourier],  # annual seasonality (fourier)
    drop=True,                   # drop terms to avoid collinearity
)

X = dp.in_sample()  # create features for dates in tunnel.index

# %%
X

# %%
y = meattt["QTY_OUT"]

model = LinearRegression(fit_intercept=False)
_ = model.fit(X, y)

y_pred = pd.Series(model.predict(X), index=y.index)
X_fore = dp.out_of_sample(steps=50)
y_fore = pd.Series(model.predict(X_fore), index=X_fore.index)

ax = y.plot(color='0.25', style='.', title="Meat Sales - Seasonal Forecast")
ax = y_pred.plot(ax=ax, label="Seasonal")
ax = y_fore.plot(ax=ax, label="Seasonal Forecast", color='C3')
_ = ax.legend()

# %% [markdown]
# HYBRID MODELS

# %%
from pathlib import Path
from warnings import simplefilter

import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from statsmodels.tsa.deterministic import CalendarFourier, DeterministicProcess
from xgboost import XGBRegressor


simplefilter("ignore")

# Set Matplotlib defaults
plt.style.use("seaborn-whitegrid")
plt.rc(
    "figure",
    autolayout=True,
    figsize=(11, 4),
    titlesize=18,
    titleweight='bold',
)
plt.rc(
    "axes",
    labelweight="bold",
    labelsize="large",
    titleweight="bold",
    titlesize=16,
    titlepad=10,
)
plot_params = dict(
    color="0.75",
    style=".-",
    markeredgecolor="0.25",
    markerfacecolor="0.25",
)

# %%
meat2 = pd.read_csv('/kaggle/input/kk-inventory/inventory_consumed.csv', parse_dates=["MOV_DATE"])
meat2 = meat2[meat2['SKU_CAT'] == 'MEAT']
meat2 = meat2.groupby(['MOV_DATE'])['QTY_OUT'].mean().sort_index()
meat2 = meat2.reset_index()

# %%
meat2 = meat2.set_index("MOV_DATE")

# %%
meat2

# %%
y = meat2.copy()

# Create trend features
dp = DeterministicProcess(
    index=y.index,  # dates from the training data
    constant=True,  # the intercept
    order=1,        # quadratic trend
    drop=True,      # drop terms to avoid collinearity
)
X = dp.in_sample()  # features for the training data

# Test on the years 2016-2019. It will be easier for us later if we
# split the date index instead of the dataframe directly.
idx_train, idx_test = train_test_split(
    y.index, test_size=10 * 4, shuffle=False,
)
X_train, X_test = X.loc[idx_train, :], X.loc[idx_test, :]
y_train, y_test = y.loc[idx_train], y.loc[idx_test]

# Fit trend model
model = LinearRegression(fit_intercept=False)
model.fit(X_train, y_train)

# Make predictions
y_fit = pd.DataFrame(
    model.predict(X_train),
    index=y_train.index,
    columns=y_train.columns,
)
y_pred = pd.DataFrame(
    model.predict(X_test),
    index=y_test.index,
    columns=y_test.columns,
)

# Plot
axs = y_train.plot(color='0.25', subplots=True, sharex=True)
axs = y_test.plot(color='0.25', subplots=True, sharex=True, ax=axs)
axs = y_fit.plot(color='C0', subplots=True, sharex=True, ax=axs)
axs = y_pred.plot(color='C3', subplots=True, sharex=True, ax=axs)
for ax in axs: ax.legend([])
_ = plt.suptitle("Trends")

# %%
# Create splits for XGBoost
X_train, X_test = X.loc[idx_train, :], X.loc[idx_test, :]
y_train, y_test = y.loc[idx_train], y.loc[idx_test]

# Convert DataFrame to Series for y_fit and y_pred
y_fit = y_fit.squeeze()    # trend from training set
y_pred = y_pred.squeeze()  # trend from test set

# Create residuals (detrended series) from the training set
y_resid = y_train.squeeze() - y_fit

# Train XGBoost on the residuals
xgb = XGBRegressor()
xgb.fit(X_train, y_resid)

# Add the predicted residuals onto the predicted trends
y_fit_boosted = pd.Series(xgb.predict(X_train), index=y_train.index) + y_fit
y_pred_boosted = pd.Series(xgb.predict(X_test), index=y_test.index) + y_pred

# Plot the boosted results
axs = y_train.plot(color='0.25', subplots=True, sharex=True)
axs = y_test.plot(color='0.25', subplots=True, sharex=True, ax=axs)
axs = y_fit_boosted.plot(color='C0', subplots=True, sharex=True, ax=axs)
axs = y_pred_boosted.plot(color='C3', subplots=True, sharex=True, ax=axs)
for ax in axs: ax.legend([])
plt.suptitle("Boosted Trends")
plt.show()

# %%
axs = y_train.plot(
    color='0.25', figsize=(11, 5), subplots=True, sharex=True,
    title=['Boosted'],
)
axs = y_test.plot(
    color='0.25', subplots=True, sharex=True, ax=axs,
)
axs = y_fit_boosted.plot(
    color='C0', subplots=True, sharex=True, ax=axs,
)
axs = y_pred_boosted.plot(
    color='C3', subplots=True, sharex=True, ax=axs,
)
for ax in axs: ax.legend([])
